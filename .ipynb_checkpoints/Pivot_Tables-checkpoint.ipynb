# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    324     67   John
# 1  2023-01-02       B   West    672     71   Mary
# 2  2023-01-03       C  North    726     28    Bob
# 3  2023-01-04       D  South    383     58  Alice
# 4  2023-01-05       A   East    852     84   John
# 5  2023-01-06       B   West    121     90   Mary
# 6  2023-01-07       C  North    853     63    Bob
# 7  2023-01-08       D  South    396     47  Alice
# 8  2023-01-09       A   East    453     43   John
# 9  2023-01-10       B   West    903     84   Mary
# 10 2023-01-11       C  North    840     27    Bob
# 11 2023-01-12       D  South    772     46  Alice
# 12 2023-01-13       A   East    119     40   John
# 13 2023-01-14       B   West    810     70   Mary
# 14 2023-01-15       C  North    613     95    Bob
# 15 2023-01-16       D  South    760     80  Alice
# 16 2023-01-17       A   East    342     78   John
# 17 2023-01-18       B   West    990     20   Mary
# 18 2023-01-19       C  North    199     45    Bob
# 19 2023-01-20       D  South    947     82  Alice

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product')
# Out:
# Product      A      B      C      D
# Region
# East     418.0    NaN    NaN    NaN
# North      NaN    NaN  646.2    NaN
# South      NaN    NaN    NaN  651.6
# West       NaN  699.2    NaN    NaN

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='min')
# Out:
# Product      A      B      C      D
# Region
# East     119.0    NaN    NaN    NaN
# North      NaN    NaN  199.0    NaN
# South      NaN    NaN    NaN  383.0
# West       NaN  121.0    NaN    NaN

# %%
pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     418.0    NaN    NaN    NaN  62.4   NaN   NaN   NaN
# North      NaN    NaN  646.2    NaN   NaN   NaN  51.6   NaN
# South      NaN    NaN    NaN  651.6   NaN   NaN   NaN  62.6
# West       NaN  699.2    NaN    NaN   NaN  67.0   NaN   NaN

# %%
pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product',aggfunc='std')
# Out:
#               Sales                                          Units             \
# Product           A           B           C           D          A          B
# Region
# East     270.921575         NaN         NaN         NaN  20.057418        NaN
# North           NaN         NaN  268.226956         NaN        NaN        NaN
# South           NaN         NaN         NaN  250.492116        NaN        NaN
# West            NaN  344.031539         NaN         NaN        NaN  27.622455
#
#
# Product          C          D
# Region
# East           NaN        NaN
# North    28.368997        NaN
# South          NaN  17.458522
# West           NaN        NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
