# %%
import numpy as np 
import seaborn as sns 
from scipy.stats import f_oneway

# %%
df=sns.load_dataset('titanic')

# %%
df=df.dropna()

# %%
class_1=df[df['pclass'] == 1]['age']
class_2=df[df['pclass'] == 2]['age']
class_3=df[df['pclass'] == 3]['age']

# %%
f_stats, p_value = f_oneway(class_1,class_2,class_3)

# %%
f_stats,p_value
# Out:
# (np.float64(9.650000210498488), np.float64(0.00010470399891167787))

# %%
if p_value<0.05:
    print('Hypothesis is rejected')
else:
    print('Accepted')
# Out:
# Hypothesis is rejected
