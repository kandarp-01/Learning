# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('student_data_100000.csv')

# %%
df.head()
# Out:
#    attendance  study_hours  past_failures  assignments_completed_pct  \
# 0       87.42        10.12              2                     100.00
# 1       71.54         1.38              3                      36.70
# 2       91.19         8.30              5                      64.38
# 3      100.00         3.52              4                      93.77
# 4       69.15         4.69              1                      72.36
#
#   parental_education family_income extracurricular internet_access  \
# 0          Secondary           Low             Yes             Yes
# 1          Secondary          High             Yes             Yes
# 2          Secondary           Low              No             Yes
# 3          Secondary           Low              No              No
# 4            Primary           Low             Yes             Yes
#
#    previous_grade  final_score risk_category
# 0           46.80        76.08          Safe
# 1           48.05        43.21     High-Risk
# ...

# %%
df.shape
# Out:
# (100000, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   attendance                 99000 non-null   float64
#  1   study_hours                99000 non-null   float64
#  2   past_failures              100000 non-null  int64
#  3   assignments_completed_pct  100000 non-null  float64
#  4   parental_education         100000 non-null  str
#  5   family_income              100000 non-null  str
#  6   extracurricular            100000 non-null  str
#  7   internet_access            100000 non-null  str
#  8   previous_grade             100000 non-null  float64
#  9   final_score                100000 non-null  float64
#  10  risk_category              100000 non-null  str
# dtypes: float64(5), int64(1), str(5)
# memory usage: 10.7 MB

# %%
df.describe()
# Out:
#          attendance   study_hours  past_failures  assignments_completed_pct  \
# count  99000.000000  99000.000000  100000.000000              100000.000000
# mean      72.972567      6.101901       1.848650                  72.929616
# std       21.562735      3.722512       1.491297                  21.656246
# min       10.000000      0.000000       0.000000                   0.000000
# 25%       58.150000      3.300000       1.000000                  58.090000
# 50%       75.065000      6.000000       2.000000                  75.070000
# 75%       91.940000      8.700000       3.000000                  91.830000
# max      100.000000     15.000000       5.000000                 100.000000
#
#        previous_grade    final_score
# count   100000.000000  100000.000000
# mean        72.967067      62.968236
# std         21.624269      15.888285
# min          0.000000       0.000000
# 25%         58.190000      52.220000
# 50%         75.040000      63.160000
# ...

# %%
df['risk_category'].unique()
# Out:
# <ArrowStringArray>
# ['Safe', 'High-Risk', 'At-Risk']
# Length: 3, dtype: str

# %%
numeric_columns=['attendance','study_hours','past_failures','assignments_completed_pct','previous_grade','final_score']

# %%
df.skew(numeric_only=True)
# Out:
# attendance                  -0.542913
# study_hours                  0.215007
# past_failures                0.348892
# assignments_completed_pct   -0.576017
# previous_grade              -0.571161
# final_score                 -0.115524
# dtype: float64

# %%
def plotting(var,ind):
    plt.subplot(2,3,ind)
    sns.histplot(df[var],kde=True)
for ind,col in enumerate(numeric_columns):
    plotting(col,ind+1)
plt.tight_layout()

# %%
atd_mean=df[df['attendance'].isna()==False]['attendance'].mean()

# %%
std_hr_mean=df[df['study_hours'].isna()==False]['study_hours'].mean()

# %%
df['attendance']=df['attendance'].fillna(atd_mean)

# %%
df['study_hours']=df['study_hours'].fillna(std_hr_mean)

# %%
df.describe()
# Out:
#           attendance    study_hours  past_failures  assignments_completed_pct  \
# count  100000.000000  100000.000000  100000.000000              100000.000000
# mean       72.972567       6.101901       1.848650                  72.929616
# std        21.454649       3.703853       1.491297                  21.656246
# min        10.000000       0.000000       0.000000                   0.000000
# 25%        58.360000       3.340000       1.000000                  58.090000
# 50%        74.740000       6.050000       2.000000                  75.070000
# 75%        91.740000       8.660000       3.000000                  91.830000
# max       100.000000      15.000000       5.000000                 100.000000
#
#        previous_grade    final_score
# count   100000.000000  100000.000000
# mean        72.967067      62.968236
# std         21.624269      15.888285
# min          0.000000       0.000000
# 25%         58.190000      52.220000
# 50%         75.040000      63.160000
# ...

# %%
df_encoded=pd.get_dummies(df,drop_first=True)

# %%
df_encoded=df_encoded.astype(int)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
numeric_columns=['attendance','study_hours','past_failures','assignments_completed_pct','previous_grade','final_score']
df_encoded[numeric_columns]=scaler.fit_transform(df[numeric_columns])

# %%
df_encoded.head()
# Out:
#    attendance  study_hours  past_failures  assignments_completed_pct  \
# 0    0.673397     1.084848       0.101489                   1.250010
# 1   -0.066772    -1.274868       0.772050                  -1.672949
# 2    0.849118     0.593466       2.113172                  -0.394790
# 3    1.259753    -0.697089       1.442611                   0.962332
# 4   -0.178171    -0.381200      -0.569071                  -0.026303
#
#    previous_grade  final_score  parental_education_Primary  \
# 0       -1.210085     0.825251                           0
# 1       -1.152279    -1.243579                           0
# 2       -0.164957    -0.130804                           0
# 3       -0.688908    -1.101335                           0
# 4       -1.036668    -1.624994                           1
#
#    parental_education_Secondary  parental_education_none  family_income_Low  \
# 0                             1                        0                  1
# ...

# %%
plt.figure(figsize=(14,14))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
numeric_columns=['attendance','study_hours','assignments_completed_pct','final_score']
sns.pairplot(df[numeric_columns])

# %%
sns.boxplot(x='risk_category',y='attendance',data=df)
# Out:
# <Axes: xlabel='risk_category', ylabel='attendance'>
