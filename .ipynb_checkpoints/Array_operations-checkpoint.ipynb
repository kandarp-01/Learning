# %%
import numpy as np

# %% [raw]
# Arithmetic operations

# %%
arr1=np.array([1,2,3,4,5])
arr2=np.array([6,7,8,9,10])

# %%
arr1+arr2
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
arr1*arr2
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
arr1^arr2
# Out:
# array([ 7,  5, 11, 13, 15])

# %%
arr1|arr2
# Out:
# array([ 7,  7, 11, 13, 15])

# %%
arr1&arr2
# Out:
# array([0, 2, 0, 0, 0])

# %%
arr1**arr2
# Out:
# array([      1,     128,    6561,  262144, 9765625])

# %% [raw]
# Matrix operations

# %%
arr1=np.arange(1,7).reshape(3,2)
arr2=np.arange(11,17).reshape(3,2)

# %%
arr1*arr2
# Out:
# array([[11, 24],
#        [39, 56],
#        [75, 96]])

# %%
arr1,arr2
# Out:
# (array([[1, 2],
#         [3, 4],
#         [5, 6]]),
#  array([[11, 12],
#         [13, 14],
#         [15, 16]]))

# %%
arr1%arr2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
arr1/arr2
# Out:
# array([[0.09090909, 0.16666667],
#        [0.23076923, 0.28571429],
#        [0.33333333, 0.375     ]])

# %%
arr1**arr2
# Out:
# array([[            1,          4096],
#        [      1594323,     268435456],
#        [  30517578125, 2821109907456]])

# %%
arr1&arr2
# Out:
# array([[1, 0],
#        [1, 4],
#        [5, 0]])

# %%
arr1@arr2
# Out:
# array([[ 39,  42,  45],
#        [ 89,  96, 103],
#        [139, 150, 161]])

# %% [raw]
# Stacking Array

# %%
np.vstack((arr1,arr2))
# Out:
# array([[ 1,  2],
#        [ 3,  4],
#        [ 5,  6],
#        [11, 12],
#        [13, 14],
#        [15, 16]])

# %%
np.hstack((arr1,arr2))
# Out:
# array([[ 1,  2, 11, 12],
#        [ 3,  4, 13, 14],
#        [ 5,  6, 15, 16]])

# %%
np.column_stack((arr1,arr2))
# Out:
# array([[ 1,  2, 11, 12],
#        [ 3,  4, 13, 14],
#        [ 5,  6, 15, 16]])

# %%
np.row_stack((arr1,arr2))
# Out:
# /var/folders/6l/65cwxjvx5zg5ssk6xb0pr7kr0000gn/T/ipykernel_5911/3845226977.py:1: DeprecationWarning: `row_stack` alias is deprecated. Use `np.vstack` directly.
#   np.row_stack((arr1,arr2))
# array([[ 1,  2],
#        [ 3,  4],
#        [ 5,  6],
#        [11, 12],
#        [13, 14],
#        [15, 16]])

# %%
arr3=np.arange(1,17).reshape(4,4)

# %%
np.vsplit(arr3,4)
# Out:
# [array([[1, 2, 3, 4]]),
#  array([[5, 6, 7, 8]]),
#  array([[ 9, 10, 11, 12]]),
#  array([[13, 14, 15, 16]])]

# %%
np.hsplit(arr3,2)
# Out:
# [array([[ 1,  2],
#         [ 5,  6],
#         [ 9, 10],
#         [13, 14]]),
#  array([[ 3,  4],
#         [ 7,  8],
#         [11, 12],
#         [15, 16]])]
