# %%
import numpy as np
import pandas as pd

# %%
labels=['A','B','C']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={1:10,2:20,3:30}

# %%
print(pd.Series(my_list,labels))
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
