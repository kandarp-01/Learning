# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('ford.csv')

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  str
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  str
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  str
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), str(3)
# memory usage: 1.6 MB

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df[df.duplicated()!=True]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 17812 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17812 non-null  str
#  1   year          17812 non-null  int64
#  2   price         17812 non-null  int64
#  3   transmission  17812 non-null  str
#  4   mileage       17812 non-null  int64
#  5   fuelType      17812 non-null  str
#  6   tax           17812 non-null  int64
#  7   mpg           17812 non-null  float64
#  8   engineSize    17812 non-null  float64
# dtypes: float64(2), int64(4), str(3)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  17812.000000  17812.000000   17812.000000  17812.000000  17812.000000
# mean    2016.862396  12269.556310   23381.146362    113.315012     57.908696
# std        2.052039   4736.285417   19419.011045     62.034603     10.132696
# min     1996.000000    495.000000       1.000000      0.000000     20.800000
# 25%     2016.000000   8999.000000   10000.000000     30.000000     52.300000
# 50%     2017.000000  11288.000000   18277.000000    145.000000     58.900000
# 75%     2018.000000  15295.000000   31098.500000    145.000000     65.700000
# max     2060.000000  54995.000000  177644.000000    580.000000    201.800000
#
#          engineSize
# count  17812.000000
# mean       1.350623
# std        0.432581
# min        0.000000
# 25%        1.000000
# 50%        1.200000
# 75%        1.500000
# max        5.000000

# %%
cols=['year','mileage','tax','mpg','engineSize']

# %%
sns.histplot(df['price'],kde=True,bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df,y='model',x='price')
# Out:
# <Axes: xlabel='price', ylabel='model'>

# %%
sns.countplot(df['model'])
# Out:
# <Axes: xlabel='count', ylabel='model'>

# %%
sns.countplot(df['transmission'])
# Out:
# <Axes: xlabel='count', ylabel='transmission'>

# %%
sns.countplot(df['fuelType'])
# Out:
# <Axes: xlabel='count', ylabel='fuelType'>

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# Petrol      12081
# Diesel       5706
# Hybrid         22
# Electric        2
# Other           1
# Name: count, dtype: int64

# %%
df["fuelType"] = df["fuelType"].replace({
    "Hybrid": "Other",
    "Electric": "Other"
})

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
X_encoded=pd.get_dummies(X,drop_first=True)

# %%
X_encoded.head()
# Out:
#    year  mileage  tax   mpg  engineSize  model_ C-MAX  model_ EcoSport  \
# 0  2017    15944  150  57.7         1.0         False            False
# 1  2018     9083  150  57.7         1.0         False            False
# 2  2017    12456  150  57.7         1.0         False            False
# 3  2019    10460  145  40.3         1.5         False            False
# 4  2019     1482  145  48.7         1.0         False            False
#
#    model_ Edge  model_ Escort  model_ Fiesta  ...  model_ S-MAX  \
# 0        False          False           True  ...         False
# 1        False          False          False  ...         False
# 2        False          False          False  ...         False
# 3        False          False           True  ...         False
# 4        False          False           True  ...         False
#
#    model_ Streetka  model_ Tourneo Connect  model_ Tourneo Custom  \
# 0            False                   False                  False
# ...

# %%
X_encoded=X_encoded.astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
cols=['model','transmission','fuelType']
X_label=X.copy()
for i in cols:
    X_label[i]=encode.fit_transform(X_label[i])

# %%
X_label.head()
# Out:
#    model  year  transmission  mileage  fuelType  tax   mpg  engineSize
# 0      5  2017             0    15944         2  150  57.7         1.0
# 1      6  2018             1     9083         2  150  57.7         1.0
# 2      6  2017             1    12456         2  150  57.7         1.0
# 3      5  2019             1    10460         2  145  40.3         1.5
# 4      5  2019             0     1482         2  145  48.7         1.0

# %%
X_label['transmission'].value_counts()
# Out:
# transmission
# 1    15383
# 0     1354
# 2     1075
# Name: count, dtype: int64

# %%
X['transmission'].value_counts()
# Out:
# transmission
# Manual       15383
# Automatic     1354
# Semi-Auto     1075
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
cols=['year','mileage','tax','mpg']
X_encoded[cols]=scaler.fit_transform(X_encoded[cols])

# %%
X_encoded
# Out:
#            year   mileage       tax       mpg  engineSize  model_ C-MAX  \
# 0      0.067059 -0.382994  0.591380 -0.042291           1             0
# 1      0.554393 -0.736317  0.591380 -0.042291           1             0
# 2      0.067059 -0.562616  0.591380 -0.042291           1             0
# 3      1.041726 -0.665405  0.510777 -1.720193           1             0
# 4      1.041726 -1.127749  0.510777 -0.930592           1             0
# ...         ...       ...       ...       ...         ...           ...
# 17961  0.067059 -0.344061  0.591380 -1.029292           1             0
# 17962 -1.394942  0.891875 -1.343079 -0.042291           1             0
# 17963 -0.907608 -0.843071 -1.504284  0.944711           1             0
# 17964  0.554393 -0.946220  0.510777 -0.042291           1             0
# 17965 -0.907608 -0.946220 -1.472043 -0.042291           1             0
#
#        model_ EcoSport  model_ Edge  model_ Escort  model_ Fiesta  ...  \
# ...

# %%
X_encoded.columns
# Out:
# Index(['year', 'mileage', 'tax', 'mpg', 'engineSize', 'model_ C-MAX',
#        'model_ EcoSport', 'model_ Edge', 'model_ Escort', 'model_ Fiesta',
#        'model_ Focus', 'model_ Fusion', 'model_ Galaxy', 'model_ Grand C-MAX',
#        'model_ Grand Tourneo Connect', 'model_ KA', 'model_ Ka+',
#        'model_ Kuga', 'model_ Mondeo', 'model_ Mustang', 'model_ Puma',
#        'model_ Ranger', 'model_ S-MAX', 'model_ Streetka',
#        'model_ Tourneo Connect', 'model_ Tourneo Custom',
#        'model_ Transit Tourneo', 'model_Focus', 'transmission_Manual',
#        'transmission_Semi-Auto', 'fuelType_Other', 'fuelType_Petrol'],
#       dtype='str')

# %%
cols=['year', 'mileage', 'tax', 'mpg', 'engineSize', 'model_ C-MAX',
       'model_ EcoSport', 'model_ Edge', 'model_ Escort', 'model_ Fiesta',
       'model_ Focus', 'model_ Fusion', 'model_ Galaxy', 'model_ Grand C-MAX',
       'model_ Grand Tourneo Connect', 'model_ KA', 'model_ Ka+',
       'model_ Kuga', 'model_ Mondeo', 'model_ Mustang', 'model_ Puma',
       'model_ Ranger', 'model_ S-MAX', 'model_ Streetka',
       'model_ Tourneo Connect', 'model_ Tourneo Custom',
       'model_ Transit Tourneo', 'model_Focus', 'transmission_Manual',
       'transmission_Semi-Auto', 'fuelType_Other', 'fuelType_Petrol']

# %%
X_encoded[cols]=scaler.fit_transform(X_encoded[cols])

# %%
X_encoded
# Out:
#            year   mileage       tax       mpg  engineSize  model_ C-MAX  \
# 0      0.067059 -0.382994  0.591380 -0.042291   -0.446958     -0.177155
# 1      0.554393 -0.736317  0.591380 -0.042291   -0.446958     -0.177155
# 2      0.067059 -0.562616  0.591380 -0.042291   -0.446958     -0.177155
# 3      1.041726 -0.665405  0.510777 -1.720193   -0.446958     -0.177155
# 4      1.041726 -1.127749  0.510777 -0.930592   -0.446958     -0.177155
# ...         ...       ...       ...       ...         ...           ...
# 17961  0.067059 -0.344061  0.591380 -1.029292   -0.446958     -0.177155
# 17962 -1.394942  0.891875 -1.343079 -0.042291   -0.446958     -0.177155
# 17963 -0.907608 -0.843071 -1.504284  0.944711   -0.446958     -0.177155
# 17964  0.554393 -0.946220  0.510777 -0.042291   -0.446958     -0.177155
# 17965 -0.907608 -0.946220 -1.472043 -0.042291   -0.446958     -0.177155
#
#        model_ EcoSport  model_ Edge  model_ Escort  model_ Fiesta  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.20, random_state=42)

# %%
model1=LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model1.predict(X_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8259046848925202

# %%
n=X_encoded.shape[0]
p=X_encoded.shape[1]

# %%
absolute_r2=1-((1-r2)*(n-1)/(n-p-1))

# %%
absolute_r2
# Out:
# 0.825591334868141

# %%
X_train,X_test, y_train, y_test = train_test_split(X_label, y, test_size=0.20, random_state=42)

# %%
from scipy.stats import pearsonr
correlations = {
    col:pearsonr(X_encoded[col],y)[0]
    for col in cols   
}
correlation_df=pd.DataFrame(list(correlations.items()),columns=['Feature', 'Pearson Correlation'])
correlation_df.sort_values(by='Pearson Correlation',ascending=False)
# Out:
#                          Feature  Pearson Correlation
# 0                           year             0.635715
# 4                     engineSize             0.495567
# 2                            tax             0.405969
# 17                   model_ Kuga             0.281926
# 19                model_ Mustang             0.267520
# 7                    model_ Edge             0.237867
# 22                  model_ S-MAX             0.147319
# 29        transmission_Semi-Auto             0.140648
# 12                 model_ Galaxy             0.133839
# 20                   model_ Puma             0.129067
# 25         model_ Tourneo Custom             0.117139
# 10                  model_ Focus             0.112554
# 31               fuelType_Hybrid             0.073356
# 14  model_ Grand Tourneo Connect             0.029859
# 24        model_ Tourneo Connect             0.014268
# 6                model_ EcoSport             0.010959
# ...

# %%
cols=[x for x in correlations if abs(correlations[x])>0.2]
cols
# Out:
# ['year',
#  'mileage',
#  'tax',
#  'mpg',
#  'engineSize',
#  'model_ Edge',
#  'model_ Fiesta',
#  'model_ Kuga',
#  'model_ Mustang',
#  'transmission_Manual',
#  'fuelType_Petrol']

# %%
df_final=X_encoded[cols]

# %%
X_train,X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.20, random_state=42)

# %%
model2=LinearRegression()
model2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model2.predict(X_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8256860539909181
